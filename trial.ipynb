# %%
import os
import google.generativeai as genai
from IPython.display import Markdown
os.environ['GOOGLE_API_KEY'] = 'AIzaSyBFqSvUjWrV_1KQRF1TP3DZNURbtNdg_r8'

genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

from langchain_google_genai import ChatGoogleGenerativeAI

model_gemini = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro-latest",
    temperature=0
)

# %%
import pandas as pd
# Define the file path
csv_file_path = './output/menus.csv'

# Read the CSV file and assign headers explicitly
df = pd.read_csv(csv_file_path, header=None, names=["FileName", "Text"])

# Display the first few rows of the DataFrame
display(df)

# Confirm the data has been successfully loaded
print(f"DataFrame loaded with {len(df)} rows and {len(df.columns)} columns.")
# Out:
#                                    FileName  \
# 0                       Sapore del Dune.pdf
# 1       Universo Gastronomico di Namecc.pdf
# 2                 L Equilibrio Quantico.pdf
# 3            L Architetto dell Universo.pdf
# 4                     L Essenza Cosmica.pdf
# 5                   Stelle Astrofisiche.pdf
# 6                   L Essenza di Asgard.pdf
# 7                        Eco di Pandora.pdf
# 8                      L Eco dei Sapori.pdf
# 9                  L Essenza delle Dune.pdf
# 10                 L Universo in Cucina.pdf
# 11                      Cosmica Essenza.pdf
# 12           L Oasi delle Dune Stellari.pdf
# 13                   Le Stelle Danzanti.pdf
# 14                    Sala del Valhalla.pdf
# 15      Stelle dell Infinito Celestiale.pdf
# 16                  Ristorante Quantico.pdf
# 17              Le Dimensioni del Gusto.pdf
# 18                            Datapizza.pdf
# 19                     Tutti a TARSvola.pdf
# ...

# %%
import pickle

with open('./data/menus_metadata.pkl', 'rb') as f:
    metadata = pickle.load(f)

metadata = metadata.reset_index(drop=True)
menus = pd.merge(df, metadata, left_index=True, right_index=True)

# %%
menus
# Out:
#                                    FileName  \
# 0                       Sapore del Dune.pdf
# 1       Universo Gastronomico di Namecc.pdf
# 2                 L Equilibrio Quantico.pdf
# 3            L Architetto dell Universo.pdf
# 4                     L Essenza Cosmica.pdf
# 5                   Stelle Astrofisiche.pdf
# 6                   L Essenza di Asgard.pdf
# 7                        Eco di Pandora.pdf
# 8                      L Eco dei Sapori.pdf
# 9                  L Essenza delle Dune.pdf
# 10                 L Universo in Cucina.pdf
# 11                      Cosmica Essenza.pdf
# 12           L Oasi delle Dune Stellari.pdf
# 13                   Le Stelle Danzanti.pdf
# 14                    Sala del Valhalla.pdf
# 15      Stelle dell Infinito Celestiale.pdf
# 16                  Ristorante Quantico.pdf
# 17              Le Dimensioni del Gusto.pdf
# 18                            Datapizza.pdf
# 19                     Tutti a TARSvola.pdf
# ...

# %%
from langchain_community.document_loaders import DataFrameLoader

loader = DataFrameLoader(menus, page_content_column="Text")
docs_data = loader.load()
docs_data[0]
# Out:
# Document(metadata={'FileName': 'Sapore del Dune.pdf', 'Ristorante': 'Sapore del Dune', 'Pianeta': 'Tatooine', 'Chef': 'Alessandra Quanti', 'Licenze': ['Psionica II', 'Temporale I', 'Gravitazionale I', 'Quantistica 13', 'Luce II', 'Tecnologia LTK II']}, page_content='Ristorante "Sapore del Dune"\nChef Alessandra Quanti\n\nNel cuore arido di Tatooine, dove i mondi si mescolano e le stelle guidano i viaggiatori intergalattici, Chef\nAlessandra Quanti porta una rivoluzione culinaria che sfida le distanze siderali. Non è raro vedere i\ncommensali rimanere incantati osservando i suoi piatti che sembrano danzare tra le dune e le stelle, frutto\ndella sua straordinaria padronanza degli stati quantici, che le permette di esplorare e materializzare le infinite\npossibilità nascoste in ogni ingrediente rarefatto del deserto.\n\nLa sua storia ebbe inizio nei laboratori di spezie di Mos Eisley, dove la passione per la gastronomia\nmolecolare si fuse con la sua profonda comprensione dell\'universo
# ...

# %%
# Possible improvements - future hypertuning of chunk_size and chunk_overlap to improve results and try different slitters
from pprint import pprint 
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs_data)
pprint(splits[0:6])
pprint(len(splits))
# Out:
# [Document(metadata={'FileName': 'Sapore del Dune.pdf', 'Ristorante': 'Sapore del Dune', 'Pianeta': 'Tatooine', 'Chef': 'Alessandra Quanti', 'Licenze': ['Psionica II', 'Temporale I', 'Gravitazionale I', 'Quantistica 13', 'Luce II', 'Tecnologia LTK II']}, page_content='Ristorante "Sapore del Dune"\nChef Alessandra Quanti\n\nNel cuore arido di Tatooine, dove i mondi si mescolano e le stelle guidano i viaggiatori intergalattici, Chef\nAlessandra Quanti porta una rivoluzione culinaria che sfida le distanze siderali. Non è raro vedere i\ncommensali rimanere incantati osservando i suoi piatti che sembrano danzare tra le dune e le stelle, frutto\ndella sua straordinaria padronanza degli stati quantici, che le permette di esplorare e materializzare le infinite\npossibilità nascoste in ogni ingrediente rarefatto del deserto.'),
# ...

# %%
doc_prova = splits[0]

# %%
template =  """
Sei un agente che dato il chunk, con i relativi metadati di Ristorante, Pianeta, Chef e Licenze,
devi andare a leggere il chunk e analizzare attentamente il suo contenuto per popolare i metadati con quelli mancanti di Ingredienti, Piatto e Tecnica.

**ESEMPIO**
INPUT:
<> 
metadata={'FileName': 'ChoCho.pdf', 'Ristorante': 'ChoCho', 'Pianeta': 'Terra', 'Chef': 'Irfan Cela', 'Licenze': ['LicenzaChef1', 'LicenzaChef2']},
page_content='Contenuto del chunck'
<>

OUTPUT:
<> 
metadata={'FileName': 'ChoCho.pdf', 'Ristorante': 'ChoCho', 'Pianeta': 'Terra', 'Chef': 'Irfan Cela',  'Licenze': ['LicenzaChef1', 'LicenzaChef2'], 
'Ingredienti': ['Cioccolato', 'Redbull'], 'Piatti': 'Nomi dei piatti', 'Tecniche': 'Spremere il cervello'}
<>

**
Dato l'INPUT nel formato descritto, devi leggere il page_content, analizzarlo e ritornare i metadatati integrati con le nuove informationi estratte, come nell'OUTPUT dell'esempio.
Se non trovi questi campi nel testo lasciali uguali ad una stringa vuota. Sii fedele ai dati che hai nel chunck, 
quindi se non trovi l'infromazione non mettere nulla.
"""

# %%
template = """
Sei un agente incaricato di analizzare un chunk di testo e di estrarre i seguenti nuovi metadati dal suo contenuto:

1. **Ingredienti**: Lista degli ingredienti trovati nel contenuto.
2. **Piatti**: Nome dei piatti menzionati nel contenuto.
3. **Tecniche**: Tecniche culinarie descritte nel contenuto.

### Istruzioni:
- Analizza il campo `page_content` del chunk.
- Estrai solo i metadati **Ingredienti**, **Piatti** e **Tecniche**.
- Se un campo non è presente nel contenuto, restituiscilo come stringa vuota (`''`).
- Ritorna l'output in formato JSON con i soli nuovi metadati.
"""

# %%
from ibm_watsonx_ai import Credentials
from ibm_watsonx_ai.foundation_models import ModelInference

credentials = Credentials(
    url="https://us-south.ml.cloud.ibm.com",
    api_key="AnzfgthfcrfRzttoXGiKZUJDMRlcB3w4uemf0PJGFFT5"
)

OVERWRITE = False


model = ModelInference(
    model_id="mistralai/mistral-large",  # Che conosciamo bene 😊🏆
    credentials=credentials,
    project_id="5c33debb-5a25-4bfe-8392-ede4b20884fe",
    params={
        "max_tokens": 1024
    }
)

# %%
# Assuming splits is your list of Document objects
for doc in splits[:2]:
    # Access page_content using dot notation
    page_content = doc.page_content
    print(page_content)
# Out:
# Ristorante "Sapore del Dune"
# Chef Alessandra Quanti
#
# Nel cuore arido di Tatooine, dove i mondi si mescolano e le stelle guidano i viaggiatori intergalattici, Chef
# Alessandra Quanti porta una rivoluzione culinaria che sfida le distanze siderali. Non è raro vedere i
# commensali rimanere incantati osservando i suoi piatti che sembrano danzare tra le dune e le stelle, frutto
# della sua straordinaria padronanza degli stati quantici, che le permette di esplorare e materializzare le infinite
# possibilità nascoste in ogni ingrediente rarefatto del deserto.
# La sua storia ebbe inizio nei laboratori di spezie di Mos Eisley, dove la passione per la gastronomia
# molecolare si fuse con la sua profonda comprensione dell'universo subatomico. Fu proprio durante un
# esperimento particolarmente intenso con i Cristalli Kyber che scoprì la sua innata capacità di percepire le
# probabilità culinarie, un dono che trasformò ogni sua creazione in un'esperienza di perfezione matematica
# ...

# %%
df = pd.DataFrame()
results = []

for doc in splits:
    content = doc.page_content
    results += [model.chat(messages=[
        {'role': 'system',
        'content': template}, 
        {'role': 'user', 
         'content': content}
    ])['choices'][0]['message']['content']]

# %%
pprint(results[20])
# Out:
# (' ```json\n'
#  '{\n'
#  '  "Ingredienti": [\n'
#  '    "Carne di Balena spaziale",\n'
#  '    "Muffa Lunare",\n'
#  '    "Foglie di Mandragora",\n'
#  '    "Pane di Luce",\n'
#  '    "Petali di Eco"\n'
#  '  ],\n'
#  '  "Piatti": "",\n'
#  '  "Tecniche": [\n'
#  '    "Marinatura Temporale Sincronizzata"\n'
#  '  ]\n'
#  '}\n'
#  '```')
